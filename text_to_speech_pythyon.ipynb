# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinfaye/Text-classification/blob/main/text_to_speech_pythyon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts
# !pip install playsound
# !pip install pysoundfile
# !pip install bitstring

# %%
# Import the Gtts module for text  
# to speech conversion 
from gtts import gTTS

# %%
# import Os module to start the audio file
import os 
from playsound import playsound
import time

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
fh = open("/content/drive/MyDrive/TextToSpeech-master/Churchill.txt", "r")
myText = fh.read().replace("\n", " ")

# Language we want to use 
language = 'en'

# %%
output = gTTS(text=myText, lang=language, slow=False)

output.save("output.mp3")
fh.close()

# %%
# Play the converted file 
os.system("start output.mp3")
# Out:
# 32512

# %%
import IPython
IPython.display.Audio('/content/output.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
